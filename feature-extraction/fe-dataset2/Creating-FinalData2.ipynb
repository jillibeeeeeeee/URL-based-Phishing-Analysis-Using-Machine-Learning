# %% [markdown]
# # **2.B FEATURE EXTRACTION**
#
# ## Creating Final Data Set
#
#
# #### This project is worked on Jupyter Notebook

# %%
#importing required packages for this module
import pandas as pd

# %%
legitimate = pd.read_csv("/Users/jillkathleen/Desktop/Phishing-Analysis-Detection/Back-End/Extracted CSVs/from FeatureExtraction/Data-1/D2-benign-extracted.csv")
legitimate
# Out:
#       domain  ip_present  at_present  url_length  url_depth  redirection  \
# 0        NaN           0           0           0          3            0
# 1        NaN           0           0           1          3            0
# 2        NaN           0           0           0          3            0
# 3        NaN           0           0           0          1            0
# 4        NaN           0           0           0          2            0
# ...      ...         ...         ...         ...        ...          ...
# 9053     NaN           0           0           0          2            0
# 9054     NaN           0           0           0          1            0
# 9055     NaN           0           0           1          3            0
# 9056     NaN           0           0           0          2            0
# 9057     NaN           0           0           0          2            0
#
#       https_domain  short_url  prefix/suffix  dns_record  web_traffic  \
# ...

# %%
phishing = pd.read_csv("/Users/jillkathleen/Desktop/Phishing-Analysis-Detection/Back-End/Extracted CSVs/from FeatureExtraction/Data-1/D1-phish-extracted.csv")
phishing
# Out:
#                               domain  ip_present  at_present  url_length  \
# 0                mail.bacritkita.com           0           0           1
# 1               cr.mufg.jp.wlupi.com           0           0           0
# 2                    ee.uk.trg87.com           0           0           0
# 3                             bit.ly           0           0           0
# 4               lloyd-reviewdata.com           0           0           0
# ...                              ...         ...         ...         ...
# 3885       norwayposten.blogspot.com           0           0           1
# 3886  security-team-verifypayees.com           0           0           0
# 3887                      or-ca.love           0           0           0
# 3888             newdelete-payee.com           0           0           0
# 3889      pmco2020-official.jkub.com           0           0           0
#
#       url_depth  redirection  https_domain  short_url  prefix/suffix  \
# ...

# %% [markdown]
# ## Final Dataset

# %%
#Concatenating the dataframes into one 
urls = pd.concat([legitimate, phishing]).reset_index(drop=True)

urls
# Out:
#                                domain  ip_present  at_present  url_length  \
# 0                                 NaN           0           0           0
# 1                                 NaN           0           0           1
# 2                                 NaN           0           0           0
# 3                                 NaN           0           0           0
# 4                                 NaN           0           0           0
# ...                               ...         ...         ...         ...
# 12943       norwayposten.blogspot.com           0           0           1
# 12944  security-team-verifypayees.com           0           0           0
# 12945                      or-ca.love           0           0           0
# 12946             newdelete-payee.com           0           0           0
# 12947      pmco2020-official.jkub.com           0           0           0
#
#        url_depth  redirection  https_domain  short_url  prefix/suffix  \
# ...

# %%
# Storing the data in CSV file

urls.to_csv('/Users/jillkathleen/Desktop/Phishing-Analysis-Detection/Back-End/Extracted CSVs/from FeatureExtraction/Data-1/D1-final-extracted.csv', index=False)
